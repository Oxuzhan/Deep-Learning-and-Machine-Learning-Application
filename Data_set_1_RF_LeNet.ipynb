# %%
import numpy as np
import pandas as pd
import tarfile
import skimage.exposure
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
import itertools
import time


from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, LabelEncoder

import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()

import keras
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Dense, BatchNormalization
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy

# %%
folder_path = r'D:\Mines Paris-PSL\S4E\Machine learning\Exercises\Exercise_3\photo'

color_hist_feature = []
sift_features = []

# Create a SIFT object
sift = cv2.SIFT_create()

# Lists to store features and corresponding labels
features = []
labels = []

l_descp = []
l_hist = []

max_descriptors = 0
max_hist = 0
max_bow = 0

num_clusters = 10

# Iterate over all files and subfolders in the folder
for root, dirs, files in os.walk(folder_path):
    for file in files:
        # Check if the file is an image (you can adjust the condition based on your image file extensions)
        if file.endswith(('.jpg', '.png', '.jpeg')):
            # Access the image file path
            image_path = os.path.join(root, file)

            image = plt.imread(image_path)
            
            # Create histograms
            hist_phase, bins_phase = skimage.exposure.histogram(image)
            #color_hist_feature.append(hist_phase)

            # Assign visual words to each image and construct the BoVW representation
            bovw_features = []
            
            #Create a SIFT feature extraction
            # Detect and compute SIFT features

            # Convert the image to grayscale
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            keypoints, descriptors = sift.detectAndCompute(gray, None)
            
            # Check if descriptors are computed
            if descriptors is not None or descriptors.shape[0] != 0:

                # Extract the label from the folder name
                labels.append(os.path.basename(root))

                #Bag of words
                kmeans = KMeans(n_clusters=num_clusters)
                kmeans.fit(descriptors)

                bow_vector = kmeans.predict(descriptors)

                # Determine the maximum sizes of descriptors and histograms
                max_descriptors = max(max_descriptors, len(descriptors))
                max_hist = max(max_hist, len(hist_phase))
                mex_bow = max(max_bow, len(bow_vector))

                #Append the 2 features 
                features.append([descriptors.flatten(), hist_phase, bow_vector])
                l_descp.append(len(descriptors))
                l_hist.append(len(hist_phase))

# Pad or truncate the features to a fixed size
for i in range(len(features)):
    descriptors = features[i][0]
    hist_phase = features[i][1]
    bow_vector = features[i][2]

    pad_descriptors = max_descriptors - descriptors.shape[0]
    pad_hist = max_hist - len(hist_phase)
    pad_bow = max_bow - bow_vector.shape[0]

    if pad_descriptors > 0:
        descriptors = np.pad(descriptors, ((0, pad_descriptors), (0, 0)), mode='constant')
    else:
        descriptors = descriptors[:max_descriptors]

    if pad_hist > 0:
        hist_phase = np.pad(hist_phase, (0, pad_hist), mode='constant')
    else:
        hist_phase = hist_phase[:max_hist]
    
    if pad_bow > 0:
        bow_vector = np.pad(bow_vector, (0, pad_bow), mode='constant')
    else:
        bow_vector = bow_vector[:max_bow]

    # Reshape hist_phase to a 1D array
    hist_phase = hist_phase.flatten()
    bow_vector = bow_vector.flatten()

    features[i] = np.concatenate((descriptors.flatten(), hist_phase, bow_vector), axis=0)
# Out:
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\miniconda\lib\site-packages\skimage\_shared\utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# c:\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
# Create an MLP classifier
mlp = MLPClassifier()

# Define the parameter grid for tuning
param_grid = {
    'hidden_layer_sizes': [(100,), (50, 50), (100, 50, 25)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'adaptive']
}

# Create a GridSearchCV object
grid_search = GridSearchCV(mlp, param_grid, cv=5)

start = time.time()

# Perform grid search to find the best parameters
grid_search.fit(X_train, y_train)

fit_time = time.time() - start

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Train the classifier with the best parameters
mlp_best = MLPClassifier(**best_params)
mlp_best.fit(X_train, y_train)

# Predict on the test set
y_pred = mlp_best.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix using plot_confusion_matrix
plot_confusion_matrix(mlp_best, X_test, y_test, display_labels=np.unique(np.array(labels)))
plt.title('Confusion Matrix')
plt.show()

print("fit time", fit_time)
# Out:
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\miniconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# Best Score: 0.3070539419087137
# Accuracy: 0.32450331125827814
# c:\miniconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp/ipykernel_9120/1354502814.py in <module>
#
#      42
#
#      43 # Display the confusion matrix using plot_confusion_matrix
#
# ---> 44 plot_confusion_matrix(None, cm, display_labels=['Class 0', 'Class 1'])
#
#      45 plt.title('Confusion Matrix')
#
#      46 plt.show()
#
#
#
# c:\miniconda\lib\site-packages\sklearn\utils\deprecation.py in wrapped(*args, **kwargs)
#
#      86         def wrapped(*args, **kwargs):
#
#      87             warnings.warn(msg, category=FutureWarning)
#
# ---> 88             return fun(*args, **kwargs)
#
#      89
#
#      90         wrapped.__doc__ = self._update_doc(wrapped.__doc__)
#
#
#
# TypeError: plot_confusion_matrix() missing 1 required positional argument: 'y_true'

# %%
knn = KNeighborsClassifier()

# Define the parameter grid for tuning
param_grid = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Create a GridSearchCV object
grid_search = GridSearchCV(knn, param_grid, cv=5)

start = time.time()

# Perform grid search to find the best parameters
grid_search.fit(X_train, y_train)

fit_time = time.time() - start

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Train the classifier with the best parameters
knn_best = KNeighborsClassifier(**best_params)
knn_best.fit(X_train, y_train)

# Predict on the test set
y_pred = knn_best.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix using plot_confusion_matrix
plot_confusion_matrix(knn_best, X_test, y_test, display_labels=np.unique(np.array(labels)), xticks_rotation=45)
plt.title('Confusion Matrix')
plt.show()

print("fit time", fit_time)
# Out:
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# Best Score: 0.2921161825726141
# Accuracy: 0.33112582781456956
# c:\miniconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# fit time 2.773326873779297

# %%
# Create an SVM classifier
svm = SVC()

# Define the parameter grid for tuning
#'C': [0.1, 1, 10],
    #'kernel': ['linear', 'rbf'],
    #'gamma': [0.1, 1, 10]
param_grid = {'C': [0.1], 'gamma': [0.1], 'kernel': ['linear']}

# Create a GridSearchCV object
grid_search = GridSearchCV(svm, param_grid, cv=5)

start = time.time()

# Perform grid search to find the best parameters
grid_search.fit(X_train, y_train)


fit_time = time.time() - start

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Train the classifier with the best parameters
svm_best = SVC(**best_params)
svm_best.fit(X_train, y_train)

# Predict on the test set
y_pred = svm_best.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix using plot_confusion_matrix
plot_confusion_matrix(svm_best, X_test, y_test, display_labels=np.unique(np.array(labels)), xticks_rotation=45)
plt.title('Confusion Matrix')
plt.show()

print("fit time", fit_time)
# Out:
# Best Parameters: {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# Best Score: 0.2091286307053942
# Accuracy: 0.25496688741721857
# c:\miniconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# fit time 21.493425607681274

# %%
# Create a Random Forest classifier
rf = RandomForestClassifier()

# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}

# Define the parameter grid for tuning
param_grid = {'max_depth': [10], 'max_features': ['sqrt'], 'min_samples_split': [2], 'n_estimators': [300]}
#param_grid = {
    #'n_estimators': [100, 200, 300],
    #'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5, 10],
    #'max_features': ['auto', 'sqrt', 'log2']
#}

# Create a GridSearchCV object
grid_search = GridSearchCV(rf, param_grid, cv=5)

start = time.time()

# Perform grid search to find the best parameters
grid_search.fit(X_train, y_train)

fit_time = time.time() - start

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Train the classifier with the best parameters
rf_best = RandomForestClassifier(**best_params)
rf_best.fit(X_train, y_train)

# Predict on the test set
y_pred = rf_best.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix using plot_confusion_matrix
plot_confusion_matrix(rf_best, X_test, y_test, display_labels=np.unique(np.array(labels)), xticks_rotation=45)
plt.title('Confusion Matrix')
plt.show()

print(fit_time)
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# Best Score: 0.3385892116182573
# Accuracy: 0.3973509933774834
# c:\miniconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# 21.902116298675537

# %%
## Creation of the set of images

folder_path = r'D:\Mines Paris-PSL\S4E\Machine learning\Exercises\Exercise_3\photo'

images = []
labels = []

# Iterate over all files and subfolders in the folder
for root, dirs, files in os.walk(folder_path):
    for file in files:
        # Check if the file is an image (you can adjust the condition based on your image file extensions)
        if file.endswith(('.jpg', '.png', '.jpeg')):
            # Access the image file path
            image_path = os.path.join(root, file)

            image = plt.imread(image_path)

            images.append(image)
            labels.append(os.path.basename(root))

images = np.array(images)
labels = np.array(labels)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
## Lenet implementation

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

def create_LeNet_model(input_shape, num_classes):
    model = Sequential()

    # Layer 1: Convolutional layer with 6 filters, 5x5 kernel, and ReLU activation
    model.add(Conv2D(6, kernel_size=(5, 5), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Layer 2: Convolutional layer with 16 filters, 5x5 kernel, and ReLU activation
    model.add(Conv2D(16, kernel_size=(5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flatten the feature maps
    model.add(Flatten())

    # Layer 3: Fully connected layer with 120 units and ReLU activation
    model.add(Dense(120, activation='relu'))

    # Layer 4: Fully connected layer with 84 units and ReLU activation
    model.add(Dense(84, activation='relu'))

    # Layer 5: Output layer with 'num_classes' units and softmax activation
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
from sklearn.model_selection import StratifiedKFold

# Define the number of folds for cross-validation and other hyperparameters
n_folds = 5  # Number of folds for cross-validation
learning_rate = 0.001
batch_size = 32
epochs = 100

# Encode the labels
label_encoder = LabelEncoder()
labels_deep = label_encoder.fit_transform(labels)

# Initialize lists to store the evaluation metrics for each fold
val_accuracy_per_fold = []

# Perform cross-validation using StratifiedKFold
skf = StratifiedKFold(n_splits=n_folds, shuffle=True)

for fold, (train_index, val_index) in enumerate(skf.split(images, labels_deep)):
    print(f"Fold {fold + 1}")
    X_train_fold = images[train_index]
    y_train_fold = labels_deep[train_index]
    X_val_fold = images[val_index]
    y_val_fold = labels_deep[val_index]

    # Encode the labels
    #label_encoder = LabelEncoder()
    #y_train_fold = label_encoder.fit_transform(y_train_fold)
    #y_val_fold = label_encoder.fit_transform(y_val_fold)

    # Define the input shape and number of classes
    input_shape = X_train.shape[1:]
    num_classes = len(np.unique(labels))

    # Create the LeNet model
    model = create_LeNet_model(input_shape, num_classes)

    optimizer = RMSprop()

    # Compile the model
    model.compile(optimizer=optimizer, loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])

    start = time.time()

    history = model.fit(X_train_fold, y_train_fold, batch_size=batch_size, epochs=epochs, validation_data=(X_val_fold, y_val_fold))

    fit_time = time.time() - start

    # Evaluate the model on validation data
    y_val_pred = model.predict(X_val_fold)
    y_val_pred_labels = np.argmax(y_val_pred, axis=1)
    y_val_true_labels = y_val_fold
    #np.argmax(np.reshape(y_val_fold, (-1, 1)), axis=1)
    val_accuracy = accuracy_score(y_val_true_labels, y_val_pred_labels)

    val_accuracy_per_fold.append(val_accuracy)

# Calculate and display the mean and standard deviation of the evaluation metrics across folds
print("Cross-validation results:")
print(f"Mean validation accuracy: {np.mean(val_accuracy_per_fold):.4f} (+/- {np.std(val_accuracy_per_fold):.4f})")
print("fit time", fit_time)
# Out:
# Fold 1
# Epoch 1/100
# 38/38 [==============================] - 6s 157ms/step - loss: 25.5909 - accuracy: 0.1585 - val_loss: 2.1100 - val_accuracy: 0.2285
# Epoch 2/100
# 38/38 [==============================] - 6s 154ms/step - loss: 1.6682 - accuracy: 0.4207 - val_loss: 1.8517 - val_accuracy: 0.3675
# Epoch 3/100
# 38/38 [==============================] - 6s 150ms/step - loss: 0.8734 - accuracy: 0.7178 - val_loss: 2.0726 - val_accuracy: 0.4172
# Epoch 4/100
# 38/38 [==============================] - 6s 150ms/step - loss: 0.4183 - accuracy: 0.8722 - val_loss: 2.0664 - val_accuracy: 0.4768
# Epoch 5/100
# 38/38 [==============================] - 6s 152ms/step - loss: 0.1992 - accuracy: 0.9485 - val_loss: 2.3026 - val_accuracy: 0.4570
# Epoch 6/100
# 38/38 [==============================] - 6s 150ms/step - loss: 0.1220 - accuracy: 0.9643 - val_loss: 2.7532 - val_accuracy: 0.4834
# Epoch 7/100
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0840 - accuracy: 0.9793 - val_loss: 2.8436 - val_accuracy: 0.5033
# Epoch 8/100
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0473 - accuracy: 0.9909 - val_loss: 3.2999 - val_accuracy: 0.4669
# Epoch 9/100
# 38/38 [==============================] - 6s 154ms/step - loss: 0.0368 - accuracy: 0.9900 - val_loss: 2.8874 - val_accuracy: 0.4669
# Epoch 10/100
# 38/38 [==============================] - 6s 150ms/step - loss: 0.1168 - accuracy: 0.9693 - val_loss: 2.4951 - val_accuracy: 0.4669
# Epoch 11/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.1825 - accuracy: 0.9452 - val_loss: 3.4039 - val_accuracy: 0.4901
# Epoch 12/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.1196 - accuracy: 0.9701 - val_loss: 3.1849 - val_accuracy: 0.5099
# Epoch 13/100
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0430 - accuracy: 0.9867 - val_loss: 4.0231 - val_accuracy: 0.5000
# Epoch 14/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0201 - accuracy: 0.9942 - val_loss: 4.2064 - val_accuracy: 0.4967
# Epoch 15/100
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0124 - accuracy: 0.9975 - val_loss: 3.3905 - val_accuracy: 0.5232
# Epoch 16/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 4.0069 - val_accuracy: 0.5199
# Epoch 17/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.7016e-04 - accuracy: 1.0000 - val_loss: 4.0847 - val_accuracy: 0.5132
# Epoch 18/100
# 38/38 [==============================] - 6s 148ms/step - loss: 3.7788e-04 - accuracy: 1.0000 - val_loss: 4.1828 - val_accuracy: 0.5166
# Epoch 19/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.8404e-04 - accuracy: 1.0000 - val_loss: 4.3034 - val_accuracy: 0.5265
# Epoch 20/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.2434e-04 - accuracy: 1.0000 - val_loss: 4.3337 - val_accuracy: 0.5331
# Epoch 21/100
# 38/38 [==============================] - 6s 154ms/step - loss: 1.9034e-04 - accuracy: 1.0000 - val_loss: 4.3744 - val_accuracy: 0.5364
# Epoch 22/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.6598e-04 - accuracy: 1.0000 - val_loss: 4.4046 - val_accuracy: 0.5364
# Epoch 23/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.4674e-04 - accuracy: 1.0000 - val_loss: 4.4387 - val_accuracy: 0.5364
# Epoch 24/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.3095e-04 - accuracy: 1.0000 - val_loss: 4.4558 - val_accuracy: 0.5364
# Epoch 25/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.1796e-04 - accuracy: 1.0000 - val_loss: 4.4959 - val_accuracy: 0.5364
# Epoch 26/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.0704e-04 - accuracy: 1.0000 - val_loss: 4.5269 - val_accuracy: 0.5364
# Epoch 27/100
# 38/38 [==============================] - 6s 148ms/step - loss: 9.8304e-05 - accuracy: 1.0000 - val_loss: 4.5400 - val_accuracy: 0.5397
# Epoch 28/100
# 38/38 [==============================] - 6s 148ms/step - loss: 8.9894e-05 - accuracy: 1.0000 - val_loss: 4.5776 - val_accuracy: 0.5397
# Epoch 29/100
# 38/38 [==============================] - 6s 147ms/step - loss: 8.3212e-05 - accuracy: 1.0000 - val_loss: 4.5853 - val_accuracy: 0.5397
# Epoch 30/100
# 38/38 [==============================] - 6s 148ms/step - loss: 7.6896e-05 - accuracy: 1.0000 - val_loss: 4.6092 - val_accuracy: 0.5397
# Epoch 31/100
# 38/38 [==============================] - 6s 147ms/step - loss: 7.1435e-05 - accuracy: 1.0000 - val_loss: 4.6343 - val_accuracy: 0.5397
# Epoch 32/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.6800e-05 - accuracy: 1.0000 - val_loss: 4.6439 - val_accuracy: 0.5397
# Epoch 33/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.2485e-05 - accuracy: 1.0000 - val_loss: 4.6653 - val_accuracy: 0.5397
# Epoch 34/100
# 38/38 [==============================] - 6s 148ms/step - loss: 5.8653e-05 - accuracy: 1.0000 - val_loss: 4.6780 - val_accuracy: 0.5397
# Epoch 35/100
# 38/38 [==============================] - 6s 147ms/step - loss: 5.5289e-05 - accuracy: 1.0000 - val_loss: 4.6891 - val_accuracy: 0.5397
# Epoch 36/100
# 38/38 [==============================] - 6s 146ms/step - loss: 5.2073e-05 - accuracy: 1.0000 - val_loss: 4.7120 - val_accuracy: 0.5397
# Epoch 37/100
# 38/38 [==============================] - 6s 146ms/step - loss: 4.9087e-05 - accuracy: 1.0000 - val_loss: 4.7302 - val_accuracy: 0.5397
# Epoch 38/100
# 38/38 [==============================] - 6s 148ms/step - loss: 4.6421e-05 - accuracy: 1.0000 - val_loss: 4.7486 - val_accuracy: 0.5397
# Epoch 39/100
# 38/38 [==============================] - 6s 148ms/step - loss: 4.3892e-05 - accuracy: 1.0000 - val_loss: 4.7646 - val_accuracy: 0.5397
# Epoch 40/100
# 38/38 [==============================] - 6s 145ms/step - loss: 4.1534e-05 - accuracy: 1.0000 - val_loss: 4.7816 - val_accuracy: 0.5397
# Epoch 41/100
# 38/38 [==============================] - 6s 148ms/step - loss: 3.9296e-05 - accuracy: 1.0000 - val_loss: 4.7911 - val_accuracy: 0.5397
# Epoch 42/100
# 38/38 [==============================] - 6s 147ms/step - loss: 3.7413e-05 - accuracy: 1.0000 - val_loss: 4.8038 - val_accuracy: 0.5397
# Epoch 43/100
# 38/38 [==============================] - 6s 148ms/step - loss: 3.5498e-05 - accuracy: 1.0000 - val_loss: 4.8316 - val_accuracy: 0.5397
# Epoch 44/100
# 38/38 [==============================] - 6s 146ms/step - loss: 3.3745e-05 - accuracy: 1.0000 - val_loss: 4.8420 - val_accuracy: 0.5397
# Epoch 45/100
# 38/38 [==============================] - 6s 149ms/step - loss: 3.2053e-05 - accuracy: 1.0000 - val_loss: 4.8570 - val_accuracy: 0.5397
# Epoch 46/100
# 38/38 [==============================] - 6s 148ms/step - loss: 3.0530e-05 - accuracy: 1.0000 - val_loss: 4.8704 - val_accuracy: 0.5397
# Epoch 47/100
# 38/38 [==============================] - 6s 145ms/step - loss: 2.9140e-05 - accuracy: 1.0000 - val_loss: 4.8812 - val_accuracy: 0.5397
# Epoch 48/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.7891e-05 - accuracy: 1.0000 - val_loss: 4.8970 - val_accuracy: 0.5397
# Epoch 49/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.6606e-05 - accuracy: 1.0000 - val_loss: 4.9077 - val_accuracy: 0.5430
# Epoch 50/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.5504e-05 - accuracy: 1.0000 - val_loss: 4.9240 - val_accuracy: 0.5397
# Epoch 51/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.4430e-05 - accuracy: 1.0000 - val_loss: 4.9346 - val_accuracy: 0.5397
# Epoch 52/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.3351e-05 - accuracy: 1.0000 - val_loss: 4.9478 - val_accuracy: 0.5397
# Epoch 53/100
# 38/38 [==============================] - 6s 149ms/step - loss: 2.2393e-05 - accuracy: 1.0000 - val_loss: 4.9589 - val_accuracy: 0.5397
# Epoch 54/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.1502e-05 - accuracy: 1.0000 - val_loss: 4.9727 - val_accuracy: 0.5397
# Epoch 55/100
# 38/38 [==============================] - 6s 149ms/step - loss: 2.0629e-05 - accuracy: 1.0000 - val_loss: 4.9794 - val_accuracy: 0.5397
# Epoch 56/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.9824e-05 - accuracy: 1.0000 - val_loss: 4.9958 - val_accuracy: 0.5397
# Epoch 57/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.9072e-05 - accuracy: 1.0000 - val_loss: 5.0019 - val_accuracy: 0.5397
# Epoch 58/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.8374e-05 - accuracy: 1.0000 - val_loss: 5.0157 - val_accuracy: 0.5397
# Epoch 59/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.7700e-05 - accuracy: 1.0000 - val_loss: 5.0221 - val_accuracy: 0.5397
# Epoch 60/100
# 38/38 [==============================] - 6s 145ms/step - loss: 1.7079e-05 - accuracy: 1.0000 - val_loss: 5.0335 - val_accuracy: 0.5397
# Epoch 61/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.6468e-05 - accuracy: 1.0000 - val_loss: 5.0380 - val_accuracy: 0.5397
# Epoch 62/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.5902e-05 - accuracy: 1.0000 - val_loss: 5.0506 - val_accuracy: 0.5397
# Epoch 63/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.5349e-05 - accuracy: 1.0000 - val_loss: 5.0587 - val_accuracy: 0.5397
# Epoch 64/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.4825e-05 - accuracy: 1.0000 - val_loss: 5.0698 - val_accuracy: 0.5397
# Epoch 65/100
# 38/38 [==============================] - 6s 151ms/step - loss: 1.4328e-05 - accuracy: 1.0000 - val_loss: 5.0814 - val_accuracy: 0.5397
# Epoch 66/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.3843e-05 - accuracy: 1.0000 - val_loss: 5.0883 - val_accuracy: 0.5397
# Epoch 67/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.3374e-05 - accuracy: 1.0000 - val_loss: 5.0976 - val_accuracy: 0.5397
# Epoch 68/100
# 38/38 [==============================] - 5s 145ms/step - loss: 1.2939e-05 - accuracy: 1.0000 - val_loss: 5.1085 - val_accuracy: 0.5397
# Epoch 69/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.2516e-05 - accuracy: 1.0000 - val_loss: 5.1193 - val_accuracy: 0.5397
# Epoch 70/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.2115e-05 - accuracy: 1.0000 - val_loss: 5.1270 - val_accuracy: 0.5397
# Epoch 71/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.1742e-05 - accuracy: 1.0000 - val_loss: 5.1366 - val_accuracy: 0.5397
# Epoch 72/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.1346e-05 - accuracy: 1.0000 - val_loss: 5.1471 - val_accuracy: 0.5397
# Epoch 73/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.0993e-05 - accuracy: 1.0000 - val_loss: 5.1529 - val_accuracy: 0.5397
# Epoch 74/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.0666e-05 - accuracy: 1.0000 - val_loss: 5.1628 - val_accuracy: 0.5397
# Epoch 75/100
# 38/38 [==============================] - 6s 153ms/step - loss: 1.0343e-05 - accuracy: 1.0000 - val_loss: 5.1741 - val_accuracy: 0.5397
# Epoch 76/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.0017e-05 - accuracy: 1.0000 - val_loss: 5.1796 - val_accuracy: 0.5397
# Epoch 77/100
# 38/38 [==============================] - 6s 149ms/step - loss: 9.7335e-06 - accuracy: 1.0000 - val_loss: 5.1913 - val_accuracy: 0.5397
# Epoch 78/100
# 38/38 [==============================] - 6s 146ms/step - loss: 9.4238e-06 - accuracy: 1.0000 - val_loss: 5.1970 - val_accuracy: 0.5397
# Epoch 79/100
# 38/38 [==============================] - 6s 148ms/step - loss: 9.1493e-06 - accuracy: 1.0000 - val_loss: 5.2024 - val_accuracy: 0.5397
# Epoch 80/100
# 38/38 [==============================] - 6s 148ms/step - loss: 8.8717e-06 - accuracy: 1.0000 - val_loss: 5.2134 - val_accuracy: 0.5397
# Epoch 81/100
# 38/38 [==============================] - 6s 148ms/step - loss: 8.6204e-06 - accuracy: 1.0000 - val_loss: 5.2177 - val_accuracy: 0.5397
# Epoch 82/100
# 38/38 [==============================] - 6s 146ms/step - loss: 8.3823e-06 - accuracy: 1.0000 - val_loss: 5.2316 - val_accuracy: 0.5397
# Epoch 83/100
# 38/38 [==============================] - 6s 150ms/step - loss: 8.1203e-06 - accuracy: 1.0000 - val_loss: 5.2366 - val_accuracy: 0.5397
# Epoch 84/100
# 38/38 [==============================] - 6s 148ms/step - loss: 7.8912e-06 - accuracy: 1.0000 - val_loss: 5.2466 - val_accuracy: 0.5397
# Epoch 85/100
# 38/38 [==============================] - 6s 152ms/step - loss: 7.6676e-06 - accuracy: 1.0000 - val_loss: 5.2503 - val_accuracy: 0.5397
# Epoch 86/100
# 38/38 [==============================] - 6s 151ms/step - loss: 7.4568e-06 - accuracy: 1.0000 - val_loss: 5.2622 - val_accuracy: 0.5397
# Epoch 87/100
# 38/38 [==============================] - 6s 150ms/step - loss: 7.2357e-06 - accuracy: 1.0000 - val_loss: 5.2704 - val_accuracy: 0.5397
# Epoch 88/100
# 38/38 [==============================] - 6s 148ms/step - loss: 7.0334e-06 - accuracy: 1.0000 - val_loss: 5.2768 - val_accuracy: 0.5397
# Epoch 89/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.8379e-06 - accuracy: 1.0000 - val_loss: 5.2849 - val_accuracy: 0.5397
# Epoch 90/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.6502e-06 - accuracy: 1.0000 - val_loss: 5.2898 - val_accuracy: 0.5397
# Epoch 91/100
# 38/38 [==============================] - 6s 149ms/step - loss: 6.4699e-06 - accuracy: 1.0000 - val_loss: 5.2994 - val_accuracy: 0.5430
# Epoch 92/100
# 38/38 [==============================] - 6s 149ms/step - loss: 6.2947e-06 - accuracy: 1.0000 - val_loss: 5.3070 - val_accuracy: 0.5430
# Epoch 93/100
# 38/38 [==============================] - 6s 149ms/step - loss: 6.1200e-06 - accuracy: 1.0000 - val_loss: 5.3173 - val_accuracy: 0.5430
# Epoch 94/100
# 38/38 [==============================] - 6s 148ms/step - loss: 5.9620e-06 - accuracy: 1.0000 - val_loss: 5.3226 - val_accuracy: 0.5430
# Epoch 95/100
# 38/38 [==============================] - 6s 146ms/step - loss: 5.7924e-06 - accuracy: 1.0000 - val_loss: 5.3311 - val_accuracy: 0.5430
# Epoch 96/100
# 38/38 [==============================] - 6s 148ms/step - loss: 5.6474e-06 - accuracy: 1.0000 - val_loss: 5.3407 - val_accuracy: 0.5430
# Epoch 97/100
# 38/38 [==============================] - 6s 148ms/step - loss: 5.4944e-06 - accuracy: 1.0000 - val_loss: 5.3465 - val_accuracy: 0.5430
# Epoch 98/100
# 38/38 [==============================] - 6s 148ms/step - loss: 5.3463e-06 - accuracy: 1.0000 - val_loss: 5.3526 - val_accuracy: 0.5430
# Epoch 99/100
# 38/38 [==============================] - 6s 149ms/step - loss: 5.2075e-06 - accuracy: 1.0000 - val_loss: 5.3573 - val_accuracy: 0.5430
# Epoch 100/100
# 38/38 [==============================] - 6s 147ms/step - loss: 5.0759e-06 - accuracy: 1.0000 - val_loss: 5.3622 - val_accuracy: 0.5430
# 10/10 [==============================] - 1s 39ms/step
# Fold 2
# Epoch 1/100
# 38/38 [==============================] - 6s 152ms/step - loss: 11.6562 - accuracy: 0.2423 - val_loss: 1.9518 - val_accuracy: 0.3808
# Epoch 2/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.4196 - accuracy: 0.5436 - val_loss: 1.5841 - val_accuracy: 0.4834
# Epoch 3/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.6613 - accuracy: 0.8000 - val_loss: 1.6041 - val_accuracy: 0.5199
# Epoch 4/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.2377 - accuracy: 0.9311 - val_loss: 1.8731 - val_accuracy: 0.5099
# Epoch 5/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0868 - accuracy: 0.9867 - val_loss: 1.9373 - val_accuracy: 0.5397
# Epoch 6/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0495 - accuracy: 0.9900 - val_loss: 2.0150 - val_accuracy: 0.5629
# Epoch 7/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0192 - accuracy: 0.9967 - val_loss: 2.1731 - val_accuracy: 0.5430
# Epoch 8/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 2.2410 - val_accuracy: 0.5894
# Epoch 9/100
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.1848 - val_accuracy: 0.5960
# Epoch 10/100
# 38/38 [==============================] - 6s 158ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.2550 - val_accuracy: 0.5993
# Epoch 11/100
# 38/38 [==============================] - 6s 158ms/step - loss: 5.3123e-04 - accuracy: 1.0000 - val_loss: 2.3189 - val_accuracy: 0.6026
# Epoch 12/100
# 38/38 [==============================] - 6s 149ms/step - loss: 3.9873e-04 - accuracy: 1.0000 - val_loss: 2.3754 - val_accuracy: 0.6060
# Epoch 13/100
# 38/38 [==============================] - 6s 151ms/step - loss: 3.1921e-04 - accuracy: 1.0000 - val_loss: 2.4094 - val_accuracy: 0.6126
# Epoch 14/100
# 38/38 [==============================] - 6s 155ms/step - loss: 2.6671e-04 - accuracy: 1.0000 - val_loss: 2.4465 - val_accuracy: 0.6093
# Epoch 15/100
# 38/38 [==============================] - 6s 159ms/step - loss: 2.2776e-04 - accuracy: 1.0000 - val_loss: 2.4748 - val_accuracy: 0.5993
# Epoch 16/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.9627e-04 - accuracy: 1.0000 - val_loss: 2.5119 - val_accuracy: 0.5993
# Epoch 17/100
# 38/38 [==============================] - 6s 151ms/step - loss: 1.7118e-04 - accuracy: 1.0000 - val_loss: 2.5401 - val_accuracy: 0.6026
# Epoch 18/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.5008e-04 - accuracy: 1.0000 - val_loss: 2.5794 - val_accuracy: 0.5993
# Epoch 19/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.3165e-04 - accuracy: 1.0000 - val_loss: 2.6149 - val_accuracy: 0.5993
# Epoch 20/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.1624e-04 - accuracy: 1.0000 - val_loss: 2.6446 - val_accuracy: 0.5993
# Epoch 21/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.0334e-04 - accuracy: 1.0000 - val_loss: 2.6802 - val_accuracy: 0.5993
# Epoch 22/100
# 38/38 [==============================] - 6s 149ms/step - loss: 9.1321e-05 - accuracy: 1.0000 - val_loss: 2.7065 - val_accuracy: 0.5993
# Epoch 23/100
# 38/38 [==============================] - 6s 147ms/step - loss: 8.0983e-05 - accuracy: 1.0000 - val_loss: 2.7423 - val_accuracy: 0.5993
# Epoch 24/100
# 38/38 [==============================] - 6s 147ms/step - loss: 7.2396e-05 - accuracy: 1.0000 - val_loss: 2.7751 - val_accuracy: 0.6026
# Epoch 25/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.4564e-05 - accuracy: 1.0000 - val_loss: 2.7985 - val_accuracy: 0.5960
# Epoch 26/100
# 38/38 [==============================] - 6s 150ms/step - loss: 5.8183e-05 - accuracy: 1.0000 - val_loss: 2.8231 - val_accuracy: 0.5894
# Epoch 27/100
# 38/38 [==============================] - 6s 147ms/step - loss: 5.1805e-05 - accuracy: 1.0000 - val_loss: 2.8652 - val_accuracy: 0.5894
# Epoch 28/100
# 38/38 [==============================] - 6s 148ms/step - loss: 4.5977e-05 - accuracy: 1.0000 - val_loss: 2.8821 - val_accuracy: 0.6026
# Epoch 29/100
# 38/38 [==============================] - 6s 147ms/step - loss: 4.1235e-05 - accuracy: 1.0000 - val_loss: 2.9170 - val_accuracy: 0.6026
# Epoch 30/100
# 38/38 [==============================] - 6s 150ms/step - loss: 3.6859e-05 - accuracy: 1.0000 - val_loss: 2.9471 - val_accuracy: 0.5960
# Epoch 31/100
# 38/38 [==============================] - 6s 147ms/step - loss: 3.3256e-05 - accuracy: 1.0000 - val_loss: 2.9759 - val_accuracy: 0.5927
# Epoch 32/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.9890e-05 - accuracy: 1.0000 - val_loss: 3.0100 - val_accuracy: 0.5894
# Epoch 33/100
# 38/38 [==============================] - 5s 144ms/step - loss: 2.6944e-05 - accuracy: 1.0000 - val_loss: 3.0445 - val_accuracy: 0.5894
# Epoch 34/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.4294e-05 - accuracy: 1.0000 - val_loss: 3.0710 - val_accuracy: 0.5861
# Epoch 35/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.2056e-05 - accuracy: 1.0000 - val_loss: 3.1060 - val_accuracy: 0.5795
# Epoch 36/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.9996e-05 - accuracy: 1.0000 - val_loss: 3.1319 - val_accuracy: 0.5795
# Epoch 37/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.8191e-05 - accuracy: 1.0000 - val_loss: 3.1597 - val_accuracy: 0.5828
# Epoch 38/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.6521e-05 - accuracy: 1.0000 - val_loss: 3.1787 - val_accuracy: 0.5795
# Epoch 39/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.5083e-05 - accuracy: 1.0000 - val_loss: 3.1971 - val_accuracy: 0.5861
# Epoch 40/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.3593e-05 - accuracy: 1.0000 - val_loss: 3.2221 - val_accuracy: 0.5894
# Epoch 41/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.2382e-05 - accuracy: 1.0000 - val_loss: 3.2392 - val_accuracy: 0.5894
# Epoch 42/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.1275e-05 - accuracy: 1.0000 - val_loss: 3.2550 - val_accuracy: 0.5927
# Epoch 43/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.0295e-05 - accuracy: 1.0000 - val_loss: 3.2759 - val_accuracy: 0.5861
# Epoch 44/100
# 38/38 [==============================] - 6s 146ms/step - loss: 9.3783e-06 - accuracy: 1.0000 - val_loss: 3.2934 - val_accuracy: 0.5861
# Epoch 45/100
# 38/38 [==============================] - 6s 151ms/step - loss: 8.5919e-06 - accuracy: 1.0000 - val_loss: 3.3265 - val_accuracy: 0.5861
# Epoch 46/100
# 38/38 [==============================] - 6s 150ms/step - loss: 7.8910e-06 - accuracy: 1.0000 - val_loss: 3.3456 - val_accuracy: 0.5795
# Epoch 47/100
# 38/38 [==============================] - 6s 152ms/step - loss: 7.2508e-06 - accuracy: 1.0000 - val_loss: 3.3695 - val_accuracy: 0.5795
# Epoch 48/100
# 38/38 [==============================] - 6s 159ms/step - loss: 6.6894e-06 - accuracy: 1.0000 - val_loss: 3.3931 - val_accuracy: 0.5828
# Epoch 49/100
# 38/38 [==============================] - 6s 159ms/step - loss: 6.2108e-06 - accuracy: 1.0000 - val_loss: 3.4213 - val_accuracy: 0.5828
# Epoch 50/100
# 38/38 [==============================] - 6s 164ms/step - loss: 5.7589e-06 - accuracy: 1.0000 - val_loss: 3.4381 - val_accuracy: 0.5861
# Epoch 51/100
# 38/38 [==============================] - 6s 150ms/step - loss: 5.3222e-06 - accuracy: 1.0000 - val_loss: 3.4648 - val_accuracy: 0.5894
# Epoch 52/100
# 38/38 [==============================] - 6s 149ms/step - loss: 4.9500e-06 - accuracy: 1.0000 - val_loss: 3.4910 - val_accuracy: 0.5894
# Epoch 53/100
# 38/38 [==============================] - 6s 152ms/step - loss: 4.5912e-06 - accuracy: 1.0000 - val_loss: 3.5083 - val_accuracy: 0.5960
# Epoch 54/100
# 38/38 [==============================] - 6s 151ms/step - loss: 4.2479e-06 - accuracy: 1.0000 - val_loss: 3.5374 - val_accuracy: 0.5894
# Epoch 55/100
# 38/38 [==============================] - 6s 155ms/step - loss: 3.9611e-06 - accuracy: 1.0000 - val_loss: 3.5586 - val_accuracy: 0.5894
# Epoch 56/100
# 38/38 [==============================] - 6s 153ms/step - loss: 3.6855e-06 - accuracy: 1.0000 - val_loss: 3.5969 - val_accuracy: 0.5960
# Epoch 57/100
# 38/38 [==============================] - 6s 164ms/step - loss: 3.4205e-06 - accuracy: 1.0000 - val_loss: 3.6109 - val_accuracy: 0.6026
# Epoch 58/100
# 38/38 [==============================] - 6s 161ms/step - loss: 3.2022e-06 - accuracy: 1.0000 - val_loss: 3.6327 - val_accuracy: 0.6026
# Epoch 59/100
# 38/38 [==============================] - 6s 160ms/step - loss: 2.9852e-06 - accuracy: 1.0000 - val_loss: 3.6494 - val_accuracy: 0.5993
# Epoch 60/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.7987e-06 - accuracy: 1.0000 - val_loss: 3.6650 - val_accuracy: 0.5993
# Epoch 61/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.6266e-06 - accuracy: 1.0000 - val_loss: 3.6806 - val_accuracy: 0.6026
# Epoch 62/100
# 38/38 [==============================] - 6s 157ms/step - loss: 2.4794e-06 - accuracy: 1.0000 - val_loss: 3.6954 - val_accuracy: 0.6026
# Epoch 63/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.3402e-06 - accuracy: 1.0000 - val_loss: 3.7187 - val_accuracy: 0.6026
# Epoch 64/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.1987e-06 - accuracy: 1.0000 - val_loss: 3.7283 - val_accuracy: 0.6026
# Epoch 65/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.0725e-06 - accuracy: 1.0000 - val_loss: 3.7506 - val_accuracy: 0.6026
# Epoch 66/100
# 38/38 [==============================] - 6s 152ms/step - loss: 1.9458e-06 - accuracy: 1.0000 - val_loss: 3.7697 - val_accuracy: 0.5993
# Epoch 67/100
# 38/38 [==============================] - 6s 152ms/step - loss: 1.8315e-06 - accuracy: 1.0000 - val_loss: 3.7920 - val_accuracy: 0.5993
# Epoch 68/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.7196e-06 - accuracy: 1.0000 - val_loss: 3.8064 - val_accuracy: 0.5960
# Epoch 69/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.6232e-06 - accuracy: 1.0000 - val_loss: 3.8267 - val_accuracy: 0.5960
# Epoch 70/100
# 38/38 [==============================] - 6s 157ms/step - loss: 1.5341e-06 - accuracy: 1.0000 - val_loss: 3.8450 - val_accuracy: 0.5960
# Epoch 71/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.4470e-06 - accuracy: 1.0000 - val_loss: 3.8636 - val_accuracy: 0.5960
# Epoch 72/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.3667e-06 - accuracy: 1.0000 - val_loss: 3.8759 - val_accuracy: 0.5960
# Epoch 73/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.2972e-06 - accuracy: 1.0000 - val_loss: 3.8846 - val_accuracy: 0.5960
# Epoch 74/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.2289e-06 - accuracy: 1.0000 - val_loss: 3.9013 - val_accuracy: 0.5927
# Epoch 75/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.1681e-06 - accuracy: 1.0000 - val_loss: 3.9073 - val_accuracy: 0.5894
# Epoch 76/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.1062e-06 - accuracy: 1.0000 - val_loss: 3.9232 - val_accuracy: 0.5927
# Epoch 77/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.0541e-06 - accuracy: 1.0000 - val_loss: 3.9243 - val_accuracy: 0.5927
# Epoch 78/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.0041e-06 - accuracy: 1.0000 - val_loss: 3.9412 - val_accuracy: 0.5927
# Epoch 79/100
# 38/38 [==============================] - 6s 148ms/step - loss: 9.5476e-07 - accuracy: 1.0000 - val_loss: 3.9514 - val_accuracy: 0.5894
# Epoch 80/100
# 38/38 [==============================] - 6s 149ms/step - loss: 9.0579e-07 - accuracy: 1.0000 - val_loss: 3.9672 - val_accuracy: 0.5861
# Epoch 81/100
# 38/38 [==============================] - 6s 150ms/step - loss: 8.6355e-07 - accuracy: 1.0000 - val_loss: 3.9781 - val_accuracy: 0.5894
# Epoch 82/100
# 38/38 [==============================] - 6s 148ms/step - loss: 8.2348e-07 - accuracy: 1.0000 - val_loss: 3.9845 - val_accuracy: 0.5894
# Epoch 83/100
# 38/38 [==============================] - 6s 147ms/step - loss: 7.8460e-07 - accuracy: 1.0000 - val_loss: 3.9982 - val_accuracy: 0.5894
# Epoch 84/100
# 38/38 [==============================] - 6s 149ms/step - loss: 7.4740e-07 - accuracy: 1.0000 - val_loss: 4.0057 - val_accuracy: 0.5894
# Epoch 85/100
# 38/38 [==============================] - 6s 149ms/step - loss: 7.1001e-07 - accuracy: 1.0000 - val_loss: 4.0176 - val_accuracy: 0.5927
# Epoch 86/100
# 38/38 [==============================] - 6s 149ms/step - loss: 6.7924e-07 - accuracy: 1.0000 - val_loss: 4.0281 - val_accuracy: 0.5894
# Epoch 87/100
# 38/38 [==============================] - 6s 150ms/step - loss: 6.4759e-07 - accuracy: 1.0000 - val_loss: 4.0363 - val_accuracy: 0.5861
# Epoch 88/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.2167e-07 - accuracy: 1.0000 - val_loss: 4.0484 - val_accuracy: 0.5828
# Epoch 89/100
# 38/38 [==============================] - 6s 149ms/step - loss: 5.9001e-07 - accuracy: 1.0000 - val_loss: 4.0598 - val_accuracy: 0.5861
# Epoch 90/100
# 38/38 [==============================] - 6s 150ms/step - loss: 5.6379e-07 - accuracy: 1.0000 - val_loss: 4.0670 - val_accuracy: 0.5894
# Epoch 91/100
# 38/38 [==============================] - 6s 147ms/step - loss: 5.3936e-07 - accuracy: 1.0000 - val_loss: 4.0775 - val_accuracy: 0.5894
# Epoch 92/100
# 38/38 [==============================] - 6s 151ms/step - loss: 5.1463e-07 - accuracy: 1.0000 - val_loss: 4.0827 - val_accuracy: 0.5927
# Epoch 93/100
# 38/38 [==============================] - 6s 146ms/step - loss: 4.9514e-07 - accuracy: 1.0000 - val_loss: 4.0911 - val_accuracy: 0.5894
# Epoch 94/100
# 38/38 [==============================] - 6s 147ms/step - loss: 4.7397e-07 - accuracy: 1.0000 - val_loss: 4.0997 - val_accuracy: 0.5894
# Epoch 95/100
# 38/38 [==============================] - 6s 149ms/step - loss: 4.5468e-07 - accuracy: 1.0000 - val_loss: 4.1170 - val_accuracy: 0.5894
# Epoch 96/100
# 38/38 [==============================] - 6s 149ms/step - loss: 4.3568e-07 - accuracy: 1.0000 - val_loss: 4.1270 - val_accuracy: 0.5894
# Epoch 97/100
# 38/38 [==============================] - 6s 148ms/step - loss: 4.1827e-07 - accuracy: 1.0000 - val_loss: 4.1308 - val_accuracy: 0.5894
# Epoch 98/100
# 38/38 [==============================] - 6s 148ms/step - loss: 4.0165e-07 - accuracy: 1.0000 - val_loss: 4.1425 - val_accuracy: 0.5927
# Epoch 99/100
# 38/38 [==============================] - 6s 147ms/step - loss: 3.8632e-07 - accuracy: 1.0000 - val_loss: 4.1540 - val_accuracy: 0.5960
# Epoch 100/100
# 38/38 [==============================] - 6s 149ms/step - loss: 3.7098e-07 - accuracy: 1.0000 - val_loss: 4.1625 - val_accuracy: 0.5927
# 10/10 [==============================] - 1s 41ms/step
# Fold 3
# Epoch 1/100
# 38/38 [==============================] - 6s 154ms/step - loss: 34.1927 - accuracy: 0.1708 - val_loss: 2.1029 - val_accuracy: 0.2625
# Epoch 2/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.6900 - accuracy: 0.4411 - val_loss: 1.8162 - val_accuracy: 0.3953
# Epoch 3/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.9467 - accuracy: 0.6849 - val_loss: 1.7459 - val_accuracy: 0.4286
# Epoch 4/100
# 38/38 [==============================] - 6s 163ms/step - loss: 0.4183 - accuracy: 0.8748 - val_loss: 1.8306 - val_accuracy: 0.4850
# Epoch 5/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.1755 - accuracy: 0.9519 - val_loss: 2.1871 - val_accuracy: 0.4684
# Epoch 6/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0948 - accuracy: 0.9834 - val_loss: 2.1405 - val_accuracy: 0.5150
# Epoch 7/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0725 - accuracy: 0.9818 - val_loss: 2.2914 - val_accuracy: 0.5150
# Epoch 8/100
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0669 - accuracy: 0.9859 - val_loss: 2.4002 - val_accuracy: 0.5083
# Epoch 9/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0375 - accuracy: 0.9925 - val_loss: 2.3264 - val_accuracy: 0.5482
# Epoch 10/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0142 - accuracy: 0.9983 - val_loss: 2.4168 - val_accuracy: 0.5581
# Epoch 11/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0180 - accuracy: 0.9959 - val_loss: 2.6775 - val_accuracy: 0.4983
# Epoch 12/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0149 - accuracy: 0.9967 - val_loss: 2.6300 - val_accuracy: 0.5216
# Epoch 13/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.6333 - val_accuracy: 0.5349
# Epoch 14/100
# 38/38 [==============================] - 6s 152ms/step - loss: 8.5719e-04 - accuracy: 1.0000 - val_loss: 2.7086 - val_accuracy: 0.5449
# Epoch 15/100
# 38/38 [==============================] - 6s 155ms/step - loss: 4.0123e-04 - accuracy: 1.0000 - val_loss: 2.8078 - val_accuracy: 0.5415
# Epoch 16/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.9743e-04 - accuracy: 1.0000 - val_loss: 2.8452 - val_accuracy: 0.5415
# Epoch 17/100
# 38/38 [==============================] - 6s 160ms/step - loss: 2.4126e-04 - accuracy: 1.0000 - val_loss: 2.8749 - val_accuracy: 0.5449
# Epoch 18/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.0576e-04 - accuracy: 1.0000 - val_loss: 2.9100 - val_accuracy: 0.5449
# Epoch 19/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.7880e-04 - accuracy: 1.0000 - val_loss: 2.9358 - val_accuracy: 0.5482
# Epoch 20/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.5691e-04 - accuracy: 1.0000 - val_loss: 2.9612 - val_accuracy: 0.5482
# Epoch 21/100
# 38/38 [==============================] - 6s 152ms/step - loss: 1.3987e-04 - accuracy: 1.0000 - val_loss: 2.9848 - val_accuracy: 0.5449
# Epoch 22/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.2574e-04 - accuracy: 1.0000 - val_loss: 3.0071 - val_accuracy: 0.5449
# Epoch 23/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.1392e-04 - accuracy: 1.0000 - val_loss: 3.0215 - val_accuracy: 0.5449
# Epoch 24/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.0428e-04 - accuracy: 1.0000 - val_loss: 3.0408 - val_accuracy: 0.5449
# Epoch 25/100
# 38/38 [==============================] - 6s 148ms/step - loss: 9.5524e-05 - accuracy: 1.0000 - val_loss: 3.0627 - val_accuracy: 0.5449
# Epoch 26/100
# 38/38 [==============================] - 6s 146ms/step - loss: 8.7488e-05 - accuracy: 1.0000 - val_loss: 3.0776 - val_accuracy: 0.5415
# Epoch 27/100
# 38/38 [==============================] - 6s 148ms/step - loss: 8.0875e-05 - accuracy: 1.0000 - val_loss: 3.0919 - val_accuracy: 0.5382
# Epoch 28/100
# 38/38 [==============================] - 6s 147ms/step - loss: 7.4915e-05 - accuracy: 1.0000 - val_loss: 3.1099 - val_accuracy: 0.5382
# Epoch 29/100
# 38/38 [==============================] - 6s 151ms/step - loss: 6.9816e-05 - accuracy: 1.0000 - val_loss: 3.1251 - val_accuracy: 0.5382
# Epoch 30/100
# 38/38 [==============================] - 6s 145ms/step - loss: 6.4881e-05 - accuracy: 1.0000 - val_loss: 3.1397 - val_accuracy: 0.5382
# Epoch 31/100
# 38/38 [==============================] - 6s 151ms/step - loss: 6.0654e-05 - accuracy: 1.0000 - val_loss: 3.1530 - val_accuracy: 0.5382
# Epoch 32/100
# 38/38 [==============================] - 6s 157ms/step - loss: 5.6771e-05 - accuracy: 1.0000 - val_loss: 3.1692 - val_accuracy: 0.5382
# Epoch 33/100
# 38/38 [==============================] - 6s 157ms/step - loss: 5.3342e-05 - accuracy: 1.0000 - val_loss: 3.1838 - val_accuracy: 0.5382
# Epoch 34/100
# 38/38 [==============================] - 6s 161ms/step - loss: 5.0083e-05 - accuracy: 1.0000 - val_loss: 3.1919 - val_accuracy: 0.5415
# Epoch 35/100
# 38/38 [==============================] - 6s 159ms/step - loss: 4.7113e-05 - accuracy: 1.0000 - val_loss: 3.2090 - val_accuracy: 0.5415
# Epoch 36/100
# 38/38 [==============================] - 6s 159ms/step - loss: 4.4424e-05 - accuracy: 1.0000 - val_loss: 3.2205 - val_accuracy: 0.5415
# Epoch 37/100
# 38/38 [==============================] - 6s 156ms/step - loss: 4.1986e-05 - accuracy: 1.0000 - val_loss: 3.2345 - val_accuracy: 0.5449
# Epoch 38/100
# 38/38 [==============================] - 6s 159ms/step - loss: 3.9792e-05 - accuracy: 1.0000 - val_loss: 3.2489 - val_accuracy: 0.5449
# Epoch 39/100
# 38/38 [==============================] - 6s 156ms/step - loss: 3.7588e-05 - accuracy: 1.0000 - val_loss: 3.2639 - val_accuracy: 0.5449
# Epoch 40/100
# 38/38 [==============================] - 6s 155ms/step - loss: 3.5648e-05 - accuracy: 1.0000 - val_loss: 3.2757 - val_accuracy: 0.5449
# Epoch 41/100
# 38/38 [==============================] - 6s 162ms/step - loss: 3.3890e-05 - accuracy: 1.0000 - val_loss: 3.2898 - val_accuracy: 0.5449
# Epoch 42/100
# 38/38 [==============================] - 6s 161ms/step - loss: 3.2212e-05 - accuracy: 1.0000 - val_loss: 3.3008 - val_accuracy: 0.5449
# Epoch 43/100
# 38/38 [==============================] - 6s 158ms/step - loss: 3.0726e-05 - accuracy: 1.0000 - val_loss: 3.3114 - val_accuracy: 0.5449
# Epoch 44/100
# 38/38 [==============================] - 6s 152ms/step - loss: 2.9207e-05 - accuracy: 1.0000 - val_loss: 3.3251 - val_accuracy: 0.5449
# Epoch 45/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.7804e-05 - accuracy: 1.0000 - val_loss: 3.3387 - val_accuracy: 0.5449
# Epoch 46/100
# 38/38 [==============================] - 6s 146ms/step - loss: 2.6498e-05 - accuracy: 1.0000 - val_loss: 3.3506 - val_accuracy: 0.5415
# Epoch 47/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.5293e-05 - accuracy: 1.0000 - val_loss: 3.3604 - val_accuracy: 0.5415
# Epoch 48/100
# 38/38 [==============================] - 6s 149ms/step - loss: 2.4143e-05 - accuracy: 1.0000 - val_loss: 3.3745 - val_accuracy: 0.5415
# Epoch 49/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.3084e-05 - accuracy: 1.0000 - val_loss: 3.3863 - val_accuracy: 0.5415
# Epoch 50/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.2078e-05 - accuracy: 1.0000 - val_loss: 3.3990 - val_accuracy: 0.5382
# Epoch 51/100
# 38/38 [==============================] - 6s 146ms/step - loss: 2.1176e-05 - accuracy: 1.0000 - val_loss: 3.4112 - val_accuracy: 0.5382
# Epoch 52/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.0264e-05 - accuracy: 1.0000 - val_loss: 3.4202 - val_accuracy: 0.5382
# Epoch 53/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.9413e-05 - accuracy: 1.0000 - val_loss: 3.4341 - val_accuracy: 0.5382
# Epoch 54/100
# 38/38 [==============================] - 5s 145ms/step - loss: 1.8657e-05 - accuracy: 1.0000 - val_loss: 3.4451 - val_accuracy: 0.5382
# Epoch 55/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.7902e-05 - accuracy: 1.0000 - val_loss: 3.4588 - val_accuracy: 0.5382
# Epoch 56/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.7201e-05 - accuracy: 1.0000 - val_loss: 3.4704 - val_accuracy: 0.5415
# Epoch 57/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.6531e-05 - accuracy: 1.0000 - val_loss: 3.4812 - val_accuracy: 0.5415
# Epoch 58/100
# 38/38 [==============================] - 6s 152ms/step - loss: 1.5880e-05 - accuracy: 1.0000 - val_loss: 3.4902 - val_accuracy: 0.5415
# Epoch 59/100
# 38/38 [==============================] - 6s 159ms/step - loss: 1.5269e-05 - accuracy: 1.0000 - val_loss: 3.5053 - val_accuracy: 0.5415
# Epoch 60/100
# 38/38 [==============================] - 6s 159ms/step - loss: 1.4693e-05 - accuracy: 1.0000 - val_loss: 3.5158 - val_accuracy: 0.5382
# Epoch 61/100
# 38/38 [==============================] - 6s 155ms/step - loss: 1.4147e-05 - accuracy: 1.0000 - val_loss: 3.5276 - val_accuracy: 0.5415
# Epoch 62/100
# 38/38 [==============================] - 6s 155ms/step - loss: 1.3631e-05 - accuracy: 1.0000 - val_loss: 3.5389 - val_accuracy: 0.5415
# Epoch 63/100
# 38/38 [==============================] - 6s 151ms/step - loss: 1.3154e-05 - accuracy: 1.0000 - val_loss: 3.5498 - val_accuracy: 0.5415
# Epoch 64/100
# 38/38 [==============================] - 6s 161ms/step - loss: 1.2667e-05 - accuracy: 1.0000 - val_loss: 3.5637 - val_accuracy: 0.5415
# Epoch 65/100
# 38/38 [==============================] - 6s 156ms/step - loss: 1.2219e-05 - accuracy: 1.0000 - val_loss: 3.5713 - val_accuracy: 0.5415
# Epoch 66/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.1796e-05 - accuracy: 1.0000 - val_loss: 3.5830 - val_accuracy: 0.5415
# Epoch 67/100
# 38/38 [==============================] - 6s 161ms/step - loss: 1.1372e-05 - accuracy: 1.0000 - val_loss: 3.5902 - val_accuracy: 0.5415
# Epoch 68/100
# 38/38 [==============================] - 6s 153ms/step - loss: 1.0985e-05 - accuracy: 1.0000 - val_loss: 3.6004 - val_accuracy: 0.5415
# Epoch 69/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.0605e-05 - accuracy: 1.0000 - val_loss: 3.6116 - val_accuracy: 0.5415
# Epoch 70/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.0253e-05 - accuracy: 1.0000 - val_loss: 3.6204 - val_accuracy: 0.5415
# Epoch 71/100
# 38/38 [==============================] - 6s 150ms/step - loss: 9.9079e-06 - accuracy: 1.0000 - val_loss: 3.6292 - val_accuracy: 0.5449
# Epoch 72/100
# 38/38 [==============================] - 6s 148ms/step - loss: 9.5927e-06 - accuracy: 1.0000 - val_loss: 3.6396 - val_accuracy: 0.5449
# Epoch 73/100
# 38/38 [==============================] - 6s 150ms/step - loss: 9.2655e-06 - accuracy: 1.0000 - val_loss: 3.6485 - val_accuracy: 0.5449
# Epoch 74/100
# 38/38 [==============================] - 6s 164ms/step - loss: 8.9718e-06 - accuracy: 1.0000 - val_loss: 3.6579 - val_accuracy: 0.5449
# Epoch 75/100
# 38/38 [==============================] - 6s 155ms/step - loss: 8.6777e-06 - accuracy: 1.0000 - val_loss: 3.6656 - val_accuracy: 0.5449
# Epoch 76/100
# 38/38 [==============================] - 6s 155ms/step - loss: 8.4001e-06 - accuracy: 1.0000 - val_loss: 3.6753 - val_accuracy: 0.5449
# Epoch 77/100
# 38/38 [==============================] - 6s 147ms/step - loss: 8.1387e-06 - accuracy: 1.0000 - val_loss: 3.6841 - val_accuracy: 0.5449
# Epoch 78/100
# 38/38 [==============================] - 6s 147ms/step - loss: 7.8791e-06 - accuracy: 1.0000 - val_loss: 3.6918 - val_accuracy: 0.5449
# Epoch 79/100
# 38/38 [==============================] - 6s 146ms/step - loss: 7.6295e-06 - accuracy: 1.0000 - val_loss: 3.7006 - val_accuracy: 0.5449
# Epoch 80/100
# 38/38 [==============================] - 6s 148ms/step - loss: 7.3891e-06 - accuracy: 1.0000 - val_loss: 3.7081 - val_accuracy: 0.5449
# Epoch 81/100
# 38/38 [==============================] - 6s 148ms/step - loss: 7.1577e-06 - accuracy: 1.0000 - val_loss: 3.7177 - val_accuracy: 0.5449
# Epoch 82/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.9341e-06 - accuracy: 1.0000 - val_loss: 3.7250 - val_accuracy: 0.5449
# Epoch 83/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.7245e-06 - accuracy: 1.0000 - val_loss: 3.7323 - val_accuracy: 0.5449
# Epoch 84/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.5182e-06 - accuracy: 1.0000 - val_loss: 3.7407 - val_accuracy: 0.5415
# Epoch 85/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.3149e-06 - accuracy: 1.0000 - val_loss: 3.7493 - val_accuracy: 0.5415
# Epoch 86/100
# 38/38 [==============================] - 6s 147ms/step - loss: 6.1244e-06 - accuracy: 1.0000 - val_loss: 3.7591 - val_accuracy: 0.5415
# Epoch 87/100
# 38/38 [==============================] - 6s 146ms/step - loss: 5.9453e-06 - accuracy: 1.0000 - val_loss: 3.7676 - val_accuracy: 0.5449
# Epoch 88/100
# 38/38 [==============================] - 6s 148ms/step - loss: 5.7643e-06 - accuracy: 1.0000 - val_loss: 3.7764 - val_accuracy: 0.5415
# Epoch 89/100
# 38/38 [==============================] - 6s 146ms/step - loss: 5.5942e-06 - accuracy: 1.0000 - val_loss: 3.7839 - val_accuracy: 0.5415
# Epoch 90/100
# 38/38 [==============================] - 6s 146ms/step - loss: 5.4368e-06 - accuracy: 1.0000 - val_loss: 3.7927 - val_accuracy: 0.5415
# Epoch 91/100
# 38/38 [==============================] - 6s 146ms/step - loss: 5.2745e-06 - accuracy: 1.0000 - val_loss: 3.8008 - val_accuracy: 0.5415
# Epoch 92/100
# 38/38 [==============================] - 6s 147ms/step - loss: 5.1227e-06 - accuracy: 1.0000 - val_loss: 3.8080 - val_accuracy: 0.5382
# Epoch 93/100
# 38/38 [==============================] - 6s 146ms/step - loss: 4.9840e-06 - accuracy: 1.0000 - val_loss: 3.8154 - val_accuracy: 0.5382
# Epoch 94/100
# 38/38 [==============================] - 6s 147ms/step - loss: 4.8364e-06 - accuracy: 1.0000 - val_loss: 3.8228 - val_accuracy: 0.5382
# Epoch 95/100
# 38/38 [==============================] - 6s 148ms/step - loss: 4.6996e-06 - accuracy: 1.0000 - val_loss: 3.8303 - val_accuracy: 0.5382
# Epoch 96/100
# 38/38 [==============================] - 6s 146ms/step - loss: 4.5744e-06 - accuracy: 1.0000 - val_loss: 3.8365 - val_accuracy: 0.5382
# Epoch 97/100
# 38/38 [==============================] - 6s 147ms/step - loss: 4.4396e-06 - accuracy: 1.0000 - val_loss: 3.8444 - val_accuracy: 0.5382
# Epoch 98/100
# 38/38 [==============================] - 6s 147ms/step - loss: 4.3146e-06 - accuracy: 1.0000 - val_loss: 3.8518 - val_accuracy: 0.5382
# Epoch 99/100
# 38/38 [==============================] - 6s 147ms/step - loss: 4.1968e-06 - accuracy: 1.0000 - val_loss: 3.8560 - val_accuracy: 0.5382
# Epoch 100/100
# 38/38 [==============================] - 6s 149ms/step - loss: 4.0866e-06 - accuracy: 1.0000 - val_loss: 3.8627 - val_accuracy: 0.5382
# 10/10 [==============================] - 0s 38ms/step
# Fold 4
# Epoch 1/100
# 38/38 [==============================] - 6s 153ms/step - loss: 34.3832 - accuracy: 0.1774 - val_loss: 2.1743 - val_accuracy: 0.1728
# Epoch 2/100
# 38/38 [==============================] - 6s 151ms/step - loss: 1.9713 - accuracy: 0.3076 - val_loss: 1.9240 - val_accuracy: 0.3754
# Epoch 3/100
# 38/38 [==============================] - 6s 150ms/step - loss: 1.2117 - accuracy: 0.5896 - val_loss: 1.7192 - val_accuracy: 0.4419
# Epoch 4/100
# 38/38 [==============================] - 6s 149ms/step - loss: 0.5182 - accuracy: 0.8300 - val_loss: 1.8665 - val_accuracy: 0.4784
# Epoch 5/100
# 38/38 [==============================] - 6s 152ms/step - loss: 0.1660 - accuracy: 0.9561 - val_loss: 1.9001 - val_accuracy: 0.5017
# Epoch 6/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0582 - accuracy: 0.9900 - val_loss: 2.4145 - val_accuracy: 0.5316
# Epoch 7/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0423 - accuracy: 0.9917 - val_loss: 2.3036 - val_accuracy: 0.5349
# Epoch 8/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0098 - accuracy: 0.9992 - val_loss: 2.4264 - val_accuracy: 0.5581
# Epoch 9/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.5442 - val_accuracy: 0.5615
# Epoch 10/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0190 - accuracy: 0.9967 - val_loss: 2.3352 - val_accuracy: 0.5349
# Epoch 11/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0393 - accuracy: 0.9892 - val_loss: 2.4008 - val_accuracy: 0.5515
# Epoch 12/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0589 - accuracy: 0.9842 - val_loss: 2.5738 - val_accuracy: 0.5249
# Epoch 13/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.1216 - accuracy: 0.9643 - val_loss: 2.4415 - val_accuracy: 0.5482
# Epoch 14/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0379 - accuracy: 0.9917 - val_loss: 2.4868 - val_accuracy: 0.5814
# Epoch 15/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0124 - accuracy: 0.9975 - val_loss: 2.9797 - val_accuracy: 0.5714
# Epoch 16/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0128 - accuracy: 0.9975 - val_loss: 2.5966 - val_accuracy: 0.5714
# Epoch 17/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 2.5798 - val_accuracy: 0.5814
# Epoch 18/100
# 38/38 [==============================] - 6s 148ms/step - loss: 9.2199e-04 - accuracy: 1.0000 - val_loss: 2.7128 - val_accuracy: 0.5814
# Epoch 19/100
# 38/38 [==============================] - 6s 147ms/step - loss: 4.3104e-04 - accuracy: 1.0000 - val_loss: 2.7761 - val_accuracy: 0.5847
# Epoch 20/100
# 38/38 [==============================] - 6s 156ms/step - loss: 3.3245e-04 - accuracy: 1.0000 - val_loss: 2.8152 - val_accuracy: 0.5914
# Epoch 21/100
# 38/38 [==============================] - 6s 156ms/step - loss: 2.7580e-04 - accuracy: 1.0000 - val_loss: 2.8584 - val_accuracy: 0.5947
# Epoch 22/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.3463e-04 - accuracy: 1.0000 - val_loss: 2.8870 - val_accuracy: 0.6013
# Epoch 23/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.0392e-04 - accuracy: 1.0000 - val_loss: 2.9162 - val_accuracy: 0.6013
# Epoch 24/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.8035e-04 - accuracy: 1.0000 - val_loss: 2.9446 - val_accuracy: 0.6013
# Epoch 25/100
# ...
# Epoch 94/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.6502e-06 - accuracy: 1.0000 - val_loss: 3.6472 - val_accuracy: 0.6080
# Epoch 95/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.4559e-06 - accuracy: 1.0000 - val_loss: 3.6521 - val_accuracy: 0.6080
# Epoch 96/100
# 38/38 [==============================] - 6s 149ms/step - loss: 6.2725e-06 - accuracy: 1.0000 - val_loss: 3.6578 - val_accuracy: 0.6080
# Epoch 97/100
# 38/38 [==============================] - 6s 150ms/step - loss: 6.0944e-06 - accuracy: 1.0000 - val_loss: 3.6629 - val_accuracy: 0.6080
# Epoch 98/100
# 38/38 [==============================] - 6s 149ms/step - loss: 5.9272e-06 - accuracy: 1.0000 - val_loss: 3.6700 - val_accuracy: 0.6080
# Epoch 99/100
# 38/38 [==============================] - 6s 154ms/step - loss: 5.7484e-06 - accuracy: 1.0000 - val_loss: 3.6749 - val_accuracy: 0.6080
# Epoch 100/100
# 38/38 [==============================] - 6s 149ms/step - loss: 5.5908e-06 - accuracy: 1.0000 - val_loss: 3.6808 - val_accuracy: 0.6080
# 10/10 [==============================] - 1s 39ms/step
# Fold 5
# Epoch 1/100
# 38/38 [==============================] - 7s 162ms/step - loss: 20.9076 - accuracy: 0.1750 - val_loss: 2.2749 - val_accuracy: 0.2425
# Epoch 2/100
# 38/38 [==============================] - 6s 160ms/step - loss: 1.8357 - accuracy: 0.4104 - val_loss: 2.1024 - val_accuracy: 0.3422
# Epoch 3/100
# 38/38 [==============================] - 6s 152ms/step - loss: 1.1770 - accuracy: 0.6318 - val_loss: 1.8653 - val_accuracy: 0.3787
# Epoch 4/100
# 38/38 [==============================] - 6s 155ms/step - loss: 0.5207 - accuracy: 0.8507 - val_loss: 1.8981 - val_accuracy: 0.4684
# Epoch 5/100
# 38/38 [==============================] - 6s 154ms/step - loss: 0.1854 - accuracy: 0.9585 - val_loss: 2.1889 - val_accuracy: 0.4983
# Epoch 6/100
# 38/38 [==============================] - 6s 144ms/step - loss: 0.0752 - accuracy: 0.9842 - val_loss: 2.5083 - val_accuracy: 0.5116
# Epoch 7/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0361 - accuracy: 0.9925 - val_loss: 2.5380 - val_accuracy: 0.4950
# Epoch 8/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0154 - accuracy: 0.9967 - val_loss: 2.5866 - val_accuracy: 0.5183
# Epoch 9/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 2.6310 - val_accuracy: 0.4917
# Epoch 10/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0060 - accuracy: 0.9992 - val_loss: 2.9764 - val_accuracy: 0.5150
# Epoch 11/100
# 38/38 [==============================] - 6s 158ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.9317 - val_accuracy: 0.5183
# Epoch 12/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.0307 - val_accuracy: 0.5282
# Epoch 13/100
# 38/38 [==============================] - 6s 158ms/step - loss: 6.2807e-04 - accuracy: 1.0000 - val_loss: 3.1506 - val_accuracy: 0.5249
# Epoch 14/100
# 38/38 [==============================] - 5s 145ms/step - loss: 4.3024e-04 - accuracy: 1.0000 - val_loss: 3.2007 - val_accuracy: 0.5183
# Epoch 15/100
# 38/38 [==============================] - 5s 143ms/step - loss: 3.4246e-04 - accuracy: 1.0000 - val_loss: 3.2585 - val_accuracy: 0.5150
# Epoch 16/100
# 38/38 [==============================] - 6s 144ms/step - loss: 2.8228e-04 - accuracy: 1.0000 - val_loss: 3.3073 - val_accuracy: 0.5150
# Epoch 17/100
# 38/38 [==============================] - 5s 143ms/step - loss: 2.3877e-04 - accuracy: 1.0000 - val_loss: 3.3532 - val_accuracy: 0.5150
# Epoch 18/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.0461e-04 - accuracy: 1.0000 - val_loss: 3.3943 - val_accuracy: 0.5183
# Epoch 19/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.7567e-04 - accuracy: 1.0000 - val_loss: 3.4312 - val_accuracy: 0.5150
# Epoch 20/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.5376e-04 - accuracy: 1.0000 - val_loss: 3.4698 - val_accuracy: 0.5150
# Epoch 21/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.3422e-04 - accuracy: 1.0000 - val_loss: 3.5035 - val_accuracy: 0.5150
# Epoch 22/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.1947e-04 - accuracy: 1.0000 - val_loss: 3.5380 - val_accuracy: 0.5216
# Epoch 23/100
# 38/38 [==============================] - 6s 145ms/step - loss: 1.0563e-04 - accuracy: 1.0000 - val_loss: 3.5658 - val_accuracy: 0.5216
# Epoch 24/100
# 38/38 [==============================] - 5s 143ms/step - loss: 9.4791e-05 - accuracy: 1.0000 - val_loss: 3.5994 - val_accuracy: 0.5183
# Epoch 25/100
# 38/38 [==============================] - 5s 144ms/step - loss: 8.4950e-05 - accuracy: 1.0000 - val_loss: 3.6271 - val_accuracy: 0.5183
# Epoch 26/100
# 38/38 [==============================] - 6s 147ms/step - loss: 7.6946e-05 - accuracy: 1.0000 - val_loss: 3.6575 - val_accuracy: 0.5183
# Epoch 27/100
# 38/38 [==============================] - 5s 142ms/step - loss: 6.9494e-05 - accuracy: 1.0000 - val_loss: 3.6853 - val_accuracy: 0.5183
# Epoch 28/100
# 38/38 [==============================] - 5s 144ms/step - loss: 6.3148e-05 - accuracy: 1.0000 - val_loss: 3.7150 - val_accuracy: 0.5183
# Epoch 29/100
# 38/38 [==============================] - 6s 145ms/step - loss: 5.7659e-05 - accuracy: 1.0000 - val_loss: 3.7378 - val_accuracy: 0.5183
# Epoch 30/100
# 38/38 [==============================] - 5s 143ms/step - loss: 5.2379e-05 - accuracy: 1.0000 - val_loss: 3.7720 - val_accuracy: 0.5183
# Epoch 31/100
# 38/38 [==============================] - 5s 144ms/step - loss: 4.7916e-05 - accuracy: 1.0000 - val_loss: 3.7953 - val_accuracy: 0.5183
# Epoch 32/100
# 38/38 [==============================] - 6s 152ms/step - loss: 4.3975e-05 - accuracy: 1.0000 - val_loss: 3.8232 - val_accuracy: 0.5183
# Epoch 33/100
# 38/38 [==============================] - 6s 149ms/step - loss: 4.0489e-05 - accuracy: 1.0000 - val_loss: 3.8477 - val_accuracy: 0.5183
# Epoch 34/100
# 38/38 [==============================] - 6s 146ms/step - loss: 3.7285e-05 - accuracy: 1.0000 - val_loss: 3.8745 - val_accuracy: 0.5150
# Epoch 35/100
# 38/38 [==============================] - 5s 143ms/step - loss: 3.4414e-05 - accuracy: 1.0000 - val_loss: 3.8984 - val_accuracy: 0.5050
# Epoch 36/100
# 38/38 [==============================] - 6s 145ms/step - loss: 3.1850e-05 - accuracy: 1.0000 - val_loss: 3.9255 - val_accuracy: 0.5017
# Epoch 37/100
# 38/38 [==============================] - 5s 142ms/step - loss: 2.9517e-05 - accuracy: 1.0000 - val_loss: 3.9512 - val_accuracy: 0.5050
# Epoch 38/100
# 38/38 [==============================] - 5s 143ms/step - loss: 2.7299e-05 - accuracy: 1.0000 - val_loss: 3.9722 - val_accuracy: 0.4983
# Epoch 39/100
# 38/38 [==============================] - 5s 144ms/step - loss: 2.5351e-05 - accuracy: 1.0000 - val_loss: 3.9931 - val_accuracy: 0.4983
# Epoch 40/100
# 38/38 [==============================] - 6s 146ms/step - loss: 2.3554e-05 - accuracy: 1.0000 - val_loss: 4.0167 - val_accuracy: 0.5017
# Epoch 41/100
# 38/38 [==============================] - 5s 144ms/step - loss: 2.1900e-05 - accuracy: 1.0000 - val_loss: 4.0355 - val_accuracy: 0.5017
# Epoch 42/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.0380e-05 - accuracy: 1.0000 - val_loss: 4.0594 - val_accuracy: 0.5017
# Epoch 43/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.8966e-05 - accuracy: 1.0000 - val_loss: 4.0833 - val_accuracy: 0.5083
# Epoch 44/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.7642e-05 - accuracy: 1.0000 - val_loss: 4.1038 - val_accuracy: 0.5083
# Epoch 45/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.6417e-05 - accuracy: 1.0000 - val_loss: 4.1263 - val_accuracy: 0.5083
# Epoch 46/100
# 38/38 [==============================] - 6s 158ms/step - loss: 1.5322e-05 - accuracy: 1.0000 - val_loss: 4.1501 - val_accuracy: 0.5050
# Epoch 47/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.4320e-05 - accuracy: 1.0000 - val_loss: 4.1710 - val_accuracy: 0.5050
# Epoch 48/100
# 38/38 [==============================] - 6s 145ms/step - loss: 1.3436e-05 - accuracy: 1.0000 - val_loss: 4.1913 - val_accuracy: 0.5017
# Epoch 49/100
# 38/38 [==============================] - 6s 144ms/step - loss: 1.2558e-05 - accuracy: 1.0000 - val_loss: 4.2124 - val_accuracy: 0.4983
# Epoch 50/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.1784e-05 - accuracy: 1.0000 - val_loss: 4.2306 - val_accuracy: 0.4917
# Epoch 51/100
# 38/38 [==============================] - 6s 154ms/step - loss: 1.1055e-05 - accuracy: 1.0000 - val_loss: 4.2525 - val_accuracy: 0.4884
# Epoch 52/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.0354e-05 - accuracy: 1.0000 - val_loss: 4.2723 - val_accuracy: 0.4850
# Epoch 53/100
# 38/38 [==============================] - 6s 151ms/step - loss: 9.7143e-06 - accuracy: 1.0000 - val_loss: 4.2881 - val_accuracy: 0.4917
# Epoch 54/100
# 38/38 [==============================] - 6s 146ms/step - loss: 9.1373e-06 - accuracy: 1.0000 - val_loss: 4.3061 - val_accuracy: 0.4884
# Epoch 55/100
# 38/38 [==============================] - 5s 144ms/step - loss: 8.6033e-06 - accuracy: 1.0000 - val_loss: 4.3254 - val_accuracy: 0.4884
# Epoch 56/100
# 38/38 [==============================] - 6s 146ms/step - loss: 8.0534e-06 - accuracy: 1.0000 - val_loss: 4.3416 - val_accuracy: 0.4884
# Epoch 57/100
# 38/38 [==============================] - 6s 154ms/step - loss: 7.5965e-06 - accuracy: 1.0000 - val_loss: 4.3580 - val_accuracy: 0.4917
# Epoch 58/100
# 38/38 [==============================] - 6s 146ms/step - loss: 7.1719e-06 - accuracy: 1.0000 - val_loss: 4.3711 - val_accuracy: 0.4950
# Epoch 59/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.7699e-06 - accuracy: 1.0000 - val_loss: 4.3863 - val_accuracy: 0.4950
# Epoch 60/100
# 38/38 [==============================] - 6s 148ms/step - loss: 6.4037e-06 - accuracy: 1.0000 - val_loss: 4.4005 - val_accuracy: 0.4950
# Epoch 61/100
# 38/38 [==============================] - 6s 145ms/step - loss: 6.0465e-06 - accuracy: 1.0000 - val_loss: 4.4137 - val_accuracy: 0.4950
# Epoch 62/100
# 38/38 [==============================] - 6s 147ms/step - loss: 5.7316e-06 - accuracy: 1.0000 - val_loss: 4.4308 - val_accuracy: 0.4950
# Epoch 63/100
# 38/38 [==============================] - 5s 145ms/step - loss: 5.4106e-06 - accuracy: 1.0000 - val_loss: 4.4445 - val_accuracy: 0.4950
# Epoch 64/100
# 38/38 [==============================] - 6s 146ms/step - loss: 5.1272e-06 - accuracy: 1.0000 - val_loss: 4.4579 - val_accuracy: 0.4950
# Epoch 65/100
# 38/38 [==============================] - 5s 144ms/step - loss: 4.8623e-06 - accuracy: 1.0000 - val_loss: 4.4762 - val_accuracy: 0.4983
# Epoch 66/100
# 38/38 [==============================] - 6s 146ms/step - loss: 4.5965e-06 - accuracy: 1.0000 - val_loss: 4.4910 - val_accuracy: 0.4950
# Epoch 67/100
# 38/38 [==============================] - 5s 143ms/step - loss: 4.3524e-06 - accuracy: 1.0000 - val_loss: 4.5037 - val_accuracy: 0.4983
# Epoch 68/100
# 38/38 [==============================] - 6s 146ms/step - loss: 4.1279e-06 - accuracy: 1.0000 - val_loss: 4.5219 - val_accuracy: 0.4983
# Epoch 69/100
# 38/38 [==============================] - 6s 145ms/step - loss: 3.9168e-06 - accuracy: 1.0000 - val_loss: 4.5361 - val_accuracy: 0.4950
# Epoch 70/100
# 38/38 [==============================] - 5s 143ms/step - loss: 3.7214e-06 - accuracy: 1.0000 - val_loss: 4.5506 - val_accuracy: 0.4983
# Epoch 71/100
# 38/38 [==============================] - 6s 147ms/step - loss: 3.5290e-06 - accuracy: 1.0000 - val_loss: 4.5709 - val_accuracy: 0.4983
# Epoch 72/100
# 38/38 [==============================] - 5s 143ms/step - loss: 3.3206e-06 - accuracy: 1.0000 - val_loss: 4.5853 - val_accuracy: 0.5017
# Epoch 73/100
# 38/38 [==============================] - 6s 146ms/step - loss: 3.1395e-06 - accuracy: 1.0000 - val_loss: 4.6002 - val_accuracy: 0.5017
# Epoch 74/100
# 38/38 [==============================] - 6s 145ms/step - loss: 2.9723e-06 - accuracy: 1.0000 - val_loss: 4.6141 - val_accuracy: 0.4983
# Epoch 75/100
# 38/38 [==============================] - 6s 148ms/step - loss: 2.8109e-06 - accuracy: 1.0000 - val_loss: 4.6286 - val_accuracy: 0.4983
# Epoch 76/100
# 38/38 [==============================] - 6s 145ms/step - loss: 2.6690e-06 - accuracy: 1.0000 - val_loss: 4.6440 - val_accuracy: 0.4983
# Epoch 77/100
# 38/38 [==============================] - 6s 147ms/step - loss: 2.5302e-06 - accuracy: 1.0000 - val_loss: 4.6577 - val_accuracy: 0.5017
# Epoch 78/100
# 38/38 [==============================] - 5s 144ms/step - loss: 2.3944e-06 - accuracy: 1.0000 - val_loss: 4.6731 - val_accuracy: 0.4983
# Epoch 79/100
# 38/38 [==============================] - 6s 146ms/step - loss: 2.2661e-06 - accuracy: 1.0000 - val_loss: 4.6848 - val_accuracy: 0.5050
# Epoch 80/100
# 38/38 [==============================] - 6s 145ms/step - loss: 2.1488e-06 - accuracy: 1.0000 - val_loss: 4.7022 - val_accuracy: 0.5083
# Epoch 81/100
# 38/38 [==============================] - 6s 150ms/step - loss: 2.0294e-06 - accuracy: 1.0000 - val_loss: 4.7187 - val_accuracy: 0.5083
# Epoch 82/100
# 38/38 [==============================] - 5s 145ms/step - loss: 1.9166e-06 - accuracy: 1.0000 - val_loss: 4.7327 - val_accuracy: 0.5050
# Epoch 83/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.8157e-06 - accuracy: 1.0000 - val_loss: 4.7492 - val_accuracy: 0.5083
# Epoch 84/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.7216e-06 - accuracy: 1.0000 - val_loss: 4.7622 - val_accuracy: 0.5050
# Epoch 85/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.6267e-06 - accuracy: 1.0000 - val_loss: 4.7729 - val_accuracy: 0.5083
# Epoch 86/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.5466e-06 - accuracy: 1.0000 - val_loss: 4.7871 - val_accuracy: 0.5083
# Epoch 87/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.4768e-06 - accuracy: 1.0000 - val_loss: 4.7960 - val_accuracy: 0.5116
# Epoch 88/100
# 38/38 [==============================] - 6s 158ms/step - loss: 1.4084e-06 - accuracy: 1.0000 - val_loss: 4.8098 - val_accuracy: 0.5116
# Epoch 89/100
# 38/38 [==============================] - 6s 156ms/step - loss: 1.3408e-06 - accuracy: 1.0000 - val_loss: 4.8216 - val_accuracy: 0.5116
# Epoch 90/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.2751e-06 - accuracy: 1.0000 - val_loss: 4.8344 - val_accuracy: 0.5083
# Epoch 91/100
# 38/38 [==============================] - 5s 145ms/step - loss: 1.2188e-06 - accuracy: 1.0000 - val_loss: 4.8457 - val_accuracy: 0.5050
# Epoch 92/100
# 38/38 [==============================] - 6s 148ms/step - loss: 1.1597e-06 - accuracy: 1.0000 - val_loss: 4.8594 - val_accuracy: 0.5083
# Epoch 93/100
# 38/38 [==============================] - 6s 146ms/step - loss: 1.1068e-06 - accuracy: 1.0000 - val_loss: 4.8718 - val_accuracy: 0.5116
# Epoch 94/100
# 38/38 [==============================] - 5s 145ms/step - loss: 1.0573e-06 - accuracy: 1.0000 - val_loss: 4.8806 - val_accuracy: 0.5083
# Epoch 95/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.0128e-06 - accuracy: 1.0000 - val_loss: 4.8866 - val_accuracy: 0.5116
# Epoch 96/100
# 38/38 [==============================] - 6s 148ms/step - loss: 9.7185e-07 - accuracy: 1.0000 - val_loss: 4.8972 - val_accuracy: 0.5116
# Epoch 97/100
# 38/38 [==============================] - 6s 146ms/step - loss: 9.3251e-07 - accuracy: 1.0000 - val_loss: 4.9098 - val_accuracy: 0.5116
# Epoch 98/100
# 38/38 [==============================] - 6s 148ms/step - loss: 8.9673e-07 - accuracy: 1.0000 - val_loss: 4.9112 - val_accuracy: 0.5116
# Epoch 99/100
# 38/38 [==============================] - 6s 147ms/step - loss: 8.5946e-07 - accuracy: 1.0000 - val_loss: 4.9229 - val_accuracy: 0.5116
# Epoch 100/100
# 38/38 [==============================] - 6s 151ms/step - loss: 8.2694e-07 - accuracy: 1.0000 - val_loss: 4.9309 - val_accuracy: 0.5116
# 10/10 [==============================] - 1s 41ms/step
# Cross-validation results:
# Mean validation accuracy: 0.5587 (+/- 0.0360)
# fit time 559.1722807884216

# %%
hist = history.history
hist.keys()

# %matplotlib inline 

colors = {'loss':'r', 'accuracy':'b', 'val_loss':'m', 'val_accuracy':'g'}
plt.figure(figsize=(10,6))
plt.title("Training Curve") 
plt.xlabel("Epoch")

for measure in hist.keys():
    color = colors[measure]
    plt.plot(range(1,epochs+1), hist[measure], color + '-', label=measure)  # use last 2 values to draw line

plt.legend(loc='upper left', scatterpoints = 1, frameon=False)

# %%
import matplotlib.pyplot as plt

# Initialize lists to store the training and validation accuracy and loss
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
## Detailed comparison : LeNet and Random forest

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
from scipy.stats import ttest_rel
from collections import Counter

# Assume you have obtained the predictions and true labels for each approach
traditional_predictions = y_pred
deep_learning_predictions = y_val_pred_labels
true_labels_deep_learning = y_val_true_labels
true_labels_traditional = y_test

# Compute the confusion matrices
traditional_cm = confusion_matrix(y_test, y_pred)
deep_learning_cm = confusion_matrix(y_val_true_labels, y_val_pred_labels)

# Plot the confusion matrices
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
axes[0].imshow(traditional_cm, cmap='Blues')
axes[0].set_title('Traditional Feature Extraction')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')
axes[1].imshow(deep_learning_cm, cmap='Blues')
axes[1].set_title('Deep Learning')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('True')
plt.tight_layout()
plt.show()

#Plot Class
plt.figure(figsize=(15,5))
plt.hist(labels, bins = 9)
plt.show()

# Calculate precision, recall, and F1-score for each class
traditional_metrics = precision_recall_fscore_support(true_labels_traditional, traditional_predictions, average=None)
deep_learning_metrics = precision_recall_fscore_support(true_labels_deep_learning, deep_learning_predictions, average=None)

# Plot class-specific metrics
classes = Counter(labels)
print(classes.keys())
x = np.arange(len(classes.keys()))
width = 0.35
fig, ax = plt.subplots(figsize=(20,5))
ax.bar(x - width/2, traditional_metrics[0], width, label='Traditional Feature Extraction')
ax.bar(x + width/2, deep_learning_metrics[0], width, label='Deep Learning')
ax.set_xticks(x)
ax.set_xticklabels(classes)
ax.set_ylabel('Precision')
ax.set_title('Precision by Class')
ax.legend()
plt.show()

# Perform statistical test
_, p_value = ttest_rel(traditional_metrics[0], deep_learning_metrics[0])
if p_value < 0.05:
    print("There is a significant difference between the two approaches.")
else:
    print("There is no significant difference between the two approaches.")
# Out:
# dict_keys(['Adam Sandler', 'Alec Baldwin', 'Angelina Jolie', 'Anna Kournikova', 'Ashton Kutcher', 'Avril Lavigne', 'Barack Obama', 'Ben Affleck', 'Beyonce Knowles'])
# There is no significant difference between the two approaches.
